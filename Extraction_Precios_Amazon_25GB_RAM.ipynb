# %% [markdown]
# # IMPORTO LA PÁGINA

# %%
import urllib.request
import requests
import sys
from bs4 import BeautifulSoup
import pandas as pd
import json
#datos_gen = urllib.request.urlopen('http://www.coes.org.pe/portal/portalinformacion/generacion')
#datos_dem=urllib.request.urlopen('http://www.coes.org.pe/portal/portalinformacion/demanda?txtFechaInicial="03/04/2020"')

# %%
#precio $activo # link &page=3

# %%
sess = requests.Session()
url = "https://www.amazon.com/s?k=laptops&language=es_US&ref=nb_sb_noss_2"
headers={"User-Agent":'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/81.0.4044.138 Safari/537.36'}
page =requests.post(url, headers=headers)
#soup = BeautifulSoup(page.content,'html.parser')

soup1 = BeautifulSoup(page.content, "html.parser")
soup2 = BeautifulSoup(soup1.prettify(), "html.parser")


#title=soup.find_all("h2",class_='a-size-mini a-spacing-none a-color-base s-line-clamp-2')

### codigo
dataframe1=pd.DataFrame(data={'Nombre':list(),'Link':list()})
for link in soup2.findAll('a',class_='a-link-normal a-text-normal'):
    soup3=BeautifulSoup(link.prettify(),'html.parser')
    xd = soup3.findAll('span',class_='a-size-medium a-color-base a-text-normal')
    a = xd[0].get_text().replace('\n','')
    #a = link.get_text().replace('\n','')
    c = link.get('href')
    df = pd.DataFrame(data={'Nombre':[a],'Link':[c]})
    dataframe1 = dataframe1.append(df)
dataframe1.reset_index(drop=True, inplace=True)
#soup2.findAll(class_='a-price-whole')

dataframe2=pd.DataFrame(data={'Precio':list(),'Link':list()})
for precio_link in soup2.findAll('a',class_='a-size-base a-link-normal a-text-normal'):
    soup3=BeautifulSoup(precio_link.prettify(),'html.parser')
    xd = soup3.findAll('span',class_='a-offscreen')
    e = xd[0].get_text().replace('\n','')
    #e = precio_link.get_text()
    f = precio_link.get('href')
    df = pd.DataFrame(data={'Precio':[e],'Link':[f]})
    dataframe2 = dataframe2.append(df)
dataframe2.reset_index(drop=True, inplace=True)
    
dataframe =pd.merge(dataframe1,dataframe2)
#dataframe =dataframe1.merge(dataframe2,on='Link')
dataframe
# Out:
# Empty DataFrame
# Columns: [Nombre, Precio, Link]
# Index: []

# %%
url = 'https://www.amazon.com/s?k=laptops&language=es_US&ref=nb_sb_noss_2&page='
def amazon_pagina(url,x):
    sess = requests.Session()
    url = url + x
    headers={"User-Agent":'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/81.0.4044.138 Safari/537.36'}
    page =requests.post(url, headers=headers)
    #soup = BeautifulSoup(page.content,'html.parser')

    soup1 = BeautifulSoup(page.content, "html.parser")
    soup2 = BeautifulSoup(soup1.prettify(), "html.parser")


    #title=soup.find_all("h2",class_='a-size-mini a-spacing-none a-color-base s-line-clamp-2')

    ### codigo
    dataframe1=pd.DataFrame(data={'Nombre':list(),'Link':list()})
    for link in soup2.findAll('a',class_='a-link-normal a-text-normal'):
        soup3=BeautifulSoup(link.prettify(),'html.parser')
        xd = soup3.findAll('span',class_='a-size-medium a-color-base a-text-normal')
        a = xd[0].get_text().replace('\n','')
        #a = link.get_text().replace('\n','')
        c = link.get('href')
        df = pd.DataFrame(data={'Nombre':[a],'Link':[c]})
        dataframe1 = dataframe1.append(df)
    dataframe1.reset_index(drop=True, inplace=True)
    #soup2.findAll(class_='a-price-whole')

    dataframe2=pd.DataFrame(data={'Precio':list(),'Link':list()})
    for precio_link in soup2.findAll('a',class_='a-size-base a-link-normal a-text-normal'):
        soup3=BeautifulSoup(precio_link.prettify(),'html.parser')
        xd = soup3.findAll('span',class_='a-offscreen')
        e = xd[0].get_text().replace('\n','')
        #e = precio_link.get_text()
        f = precio_link.get('href')
        df = pd.DataFrame(data={'Precio':[e],'Link':[f]})
        dataframe2 = dataframe2.append(df)
    dataframe2.reset_index(drop=True, inplace=True)
    
    dataframe =pd.merge(dataframe1,dataframe2)
    #dataframe =dataframe1.merge(dataframe2,on='Link')
    return(dataframe)

# %%
url = 'https://www.amazon.com/s?k=laptops&language=es_US&ref=nb_sb_noss_2&page='
dataamazon = pd.DataFrame(data={'Nombre':list(),'Link':list(),'Precio':list()})
for i in range(20):
    a = str(i+1)
    dataframe = amazon_pagina(url,a)
    dataamazon= dataamazon.append(dataframe)
dataamazon.reset_index(drop=True, inplace=True)

# %%
dataamazon.drop_duplicates(subset='Nombre', inplace=True )
dataamazon.reset_index(drop=True, inplace=True)
dataamazon[dataamazon.Nombre.str.contains("Lenovo")]
dataamazon.to_excel('dataamazon.xlsx',index = False, header=True)

# %%
dataamazon.loc[0].Link

# %%
asd = dataframe1.iloc[3,1]
we='https://www.amazon.com'+asd
we

# %%
dataframe1.iloc[11,1]

# %%
link
soup3=BeautifulSoup(link.prettify(),'html.parser')
xd = soup3.findAll('span',class_='a-size-medium a-color-base a-text-normal')
xd[0].get_text()
soup3.findAll('href',class_='a-size-medium a-color-base a-text-normal')
link

# %%
soup2.findAll('a',class_='a-link-normal a-text-normal')[-1].get('href')

# %%
precio_link
soup3=BeautifulSoup(precio_link.prettify(),'html.parser')
xd = soup3.findAll('span',class_='a-offscreen')
xd[0].get_text()

# %%
dataframe1

# %%
#&page=20
'https://www.amazon.com'

# %%
sess = requests.Session()
url ="https://www.amazon.com" +"/-/es/gp/slredirect/picassoRedirect.html/ref=pa_sp_atf_aps_sr_pg1_1?ie=UTF8&adId=A04052102LURNB4D4RAI6&url=%2FLenovo-IdeaPad-Processor-Graphics-81W0003QUS%2Fdp%2FB0862269YP%2Fref%3Dsr_1_1_sspa%3Fdchild%3D1%26keywords%3Dlaptop%26qid%3D1590174680%26sr%3D8-1-spons%26psc%3D1&qualifier=1590174680&id=3633383006645419&widgetName=sp_atf"
url ='https://www.amazon.com' + dataamazon.loc[1].Link
headers={"User-Agent":'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/81.0.4044.138 Safari/537.36'}
page =requests.post(url, headers=headers)
soup = BeautifulSoup(page.content,'html.parser')

#como no funciona solo con un soup se deben usar dos de https://www.youtube.com/watch?v=Bg9r_yLk7VY
soup1 = BeautifulSoup(page.content, "html.parser")
soup2 = BeautifulSoup(soup1.prettify(), "html.parser")

title = soup2.find(id= "productTitle").get_text()
price = soup2.find(id="priceblock_ourprice").get_text()
#para ver solo el nombre
price
url

# %%
print(price)

# %%
url="http://www.coes.org.pe/portal/portalinformacion/demanda"
payload = {'fechaInicial': '06%2F04%2F2020', 'fechaFinal': '08%2F04%2F2020'}
r2 = requests.post(url+'?'+json.dumps(payload))
datos2 =r2.json()
datos2
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File ~/.conda/envs/web-scrapping/lib/python3.10/site-packages/requests/models.py:910, in Response.json(self, **kwargs)
#     909 try:
# --> 910     return complexjson.loads(self.text, **kwargs)
#     911 except JSONDecodeError as e:
#     912     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     913     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File ~/.conda/envs/web-scrapping/lib/python3.10/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# File ~/.conda/envs/web-scrapping/lib/python3.10/json/decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     333 """Return the Python representation of ``s`` (a ``str`` instance
#     334 containing a JSON document).
#     335
#     336 """
# --> 337 obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338 end = _w(s, end).end()
#
# File ~/.conda/envs/web-scrapping/lib/python3.10/json/decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# Input In [6], in <module>
#       2 payload = {'fechaInicial': '06%2F04%2F2020', 'fechaFinal': '08%2F04%2F2020'}
#       3 r2 = requests.post(url+'?'+json.dumps(payload))
# ----> 4 datos2 =r2.json()
#       5 datos2
#
# File ~/.conda/envs/web-scrapping/lib/python3.10/site-packages/requests/models.py:917, in Response.json(self, **kwargs)
#     915     raise RequestsJSONDecodeError(e.message)
#     916 else:
# --> 917     raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
#
# JSONDecodeError: [Errno Expecting value] <!DOCTYPE html>
# <html lang="es-pe">
# <head>
#     <meta charset="utf-8" />
#     <title>.::Portal Web del COES::.</title>
#     <link rel="icon" href="/Portal/Content/Images/favicon.png" />
#     <meta name="viewport" content="width=device-width" />
#
#     <meta name="description" content="Portal Web del COES SINAC(Comité de Operación Económica del Sistema Interconectado Nacional)">
#     <meta name="keywords" content="COES, COES SINAC, Comité de Operaciones del Sistema Interconectado Nacional, Electricidad, Sector Eléctrico,
#           Programa de Operación Diario, Programa de Operación, SEIN">
#     <meta name="author" content="COES SINAC">
#
#     <link href="/Portal/Content/Css/calendar.css" rel="stylesheet" />
#     <link href="/Portal/Content/Css/table.css" rel="stylesheet" />
#     <link href="/Portal/Content/Css/css.css?v=15.23" rel="stylesheet" />
#     <link href="/Portal/Content/Css/popup.css" rel="stylesheet" />
#     <link href="/Portal/Content/Css/tabs.css" rel="stylesheet" />
#     <link href="/Portal/Content/Css/menu.css" rel="stylesheet" />
#     <script type="text/javascript">
#         var siteRoot = "/Portal/";
#         var urlRoot = "https://www.coes.org.pe";
#     </script>
#
#     <script src="/Portal/Content/Scripts/jquery.js"></script>
#     <script src="/Portal/Content/Scripts/popup.js"></script>
#     <script src="/Portal/Content/Scripts/master.js"></script>
#     <script src="/Portal/Content/Scripts/datatable.js"></script>
#     <script src="/Portal/Content/Scripts/datepicker.js"></script>
#     <script src="/Portal/Content/Scripts/jquery.easytabs.min.js"></script>
#     <script src="/Portal/Content/Scripts/menu.js"></script>
#
#     <script type="text/javascript">
#         $(document).ready(function () {
#             $('nav:first').accessibleMegaMenu();
#         });
#     </script>
#
#     <!--Google Analytics-->
#     <script>
#         (function (i, s, o, g, r, a, m) {
#             i['GoogleAnalyticsObject'] = r; i[r] = i[r] || function () {
#                 (i[r].q = i[r].q || []).push(arguments)
#             }, i[r].l = 1 * new Date(); a = s.createElement(o),
#             m = s.getElementsByTagName(o)[0]; a.async = 1; a.src = g; m.parentNode.insertBefore(a, m)
#         })(window, document, 'script', '//www.google-analytics.com/analytics.js', 'ga');
#
#         ga('create', 'UA-58739217-1', 'auto');
#         ga('send', 'pageview');
#     </script>
#
#
# </head>
# <body>
#     <div class="loyout">
#         <div class="header">
#             <div class="top-logo">
#                 <a href="/Portal/"><img src="/Portal/Content/Images/logoportal.png" /></a>
#             </div>
#             <div class="top-search">
#                 <input type="text" id="txtSearch" placeholder="Buscar..."  />
#             </div>
#             <div class="top-option">
#                 <ul class="top-option-item">
#                     <li>
#                         <a href="/Portal/" data-tooltip="Home">
#                             <img src="/Portal/Content/Images/Icons/tophome.png" />
#                         </a>
#                     </li>
#                     <li >
#                         <a href="https://www.coes.org.pe/IntranetCorporativa/" data-tooltip="Intranet">
#                             <img src="/Portal/Content/Images/Icons/topintranet.png" />
#                         </a>
#                     </li>
#                     <li >
#                         <a href="http://www.coes.org.pe/extranet" data-tooltip="Extranet">
#                             <img src="/Portal/Content/Images/Icons/topextranet.png" />
#                         </a>
#                     </li>
# 					 <li id="linkTopPortalTramite">
#                         <a href="https://tramitevirtual.coes.org.pe/" data-tooltip="Portal de Trámite Virtual">
#                             <img src="/Portal/Content/Images/Icons/portaltramite.png" />
#                         </a>
#                     </li>
#                     <li>
#                         <a href="/Portal/portalinformacion/generacion" data-tooltip="Portal de Información">
#                             <img src="/Portal/Content/Images/Icons/topportal.png" />
#                         </a>
#                     </li>
#                     <li>
#                         <a href="/Portal/Operacion/CaractSEIN/BaseDatos" data-tooltip="Características del SEIN">
#                             <img src="/Portal/Content/Images/Icons/topcaracteristicas.png" />
#                         </a>
#                     </li>
#                     <li id="linkTopIntranet">
#                         <a href="/Portal/contacto/index" data-tooltip="Contáctenos">
#                             <img src="/Portal/Content/Images/Icons/topcontactano.png" />
#                         </a>
#                     </li>
#                     <li id="linkTopExtranet">
#                         <a href="/Portal/Proveedores/Index" data-tooltip="Proveedores">
#                             <img src="/Portal/Content/Images/Icons/topproveedores.png" />
#                         </a>
#                     </li>
#                     <li id="linkTopMapa">
#                         <a href="/Portal/sitemap/index" data-tooltip="Mapa del Sitio">
#                             <img src="/Portal/Content/Images/Icons/topmapa.png" />
#                         </a>
#                     </li>
#                     <li id="linkCorreo">
#                         <a href="https://outlook.office365.com/owa" data-tooltip="Correo">
#                             <img src="/Portal/Content/Images/Icons/topcorreo.png" />
#                         </a>
#                     </li>
#                     <li>
#                         <a href="/Portal/PreguntasFrecuentes/Index" data-tooltip="Preguntas Frecuentes">
#                             <img src="/Portal/Content/Images/Icons/toppreguntas.png" />
#                         </a>
#                     </li>
#                     <li>
#                         <a href="/Portal/OportunidadesTrabajo/Index" data-tooltip="Oportunidades de Trabajo">
#                             <img src="/Portal/Content/Images/Icons/topoportunidad.png" />
#                         </a>
#                     </li>
#                     <li>
#                         <a href="JavaScript:openCalendario()" data-tooltip="Calendario COES">
#                             <img src="/Portal/Content/Images/Icons/topcalendar.png" />
#                         </a>
#
#                     </li>
#                 </ul>
#             </div>
#             <div style="clear:both"></div>
#         </div>
#         <div style="clear:both"></div>
#         <div class="menu">
#             <nav>
#                 <ul class='nav-menu'>
#     <li class='nav-item'>
#         <a href='#'>Planificación</a>
#         <div class='sub-nav'>
#             <ul class='sub-nav-group'>
#                 <li><strong>Plan de Transmisión</strong></li>
#                 <li>
#                     <ul>
#                 <li><a href='/Portal/Planificacion/PlanTransmision/ActualizacionPTT?path=Planificaci%C3%B3n%2FPlan%20de%20Transmision%2FActualizacion%20Plan%20de%20Transmision%202017%20-%202026%2F00_ABC%20del%20Plan%20de%20Transmisi%C3%B3n%2F'>ABC del Plan de Transmisión</a></li>
#                 <li><a href='/Portal/Planificacion/PlanTransmision/PrimerPT'>Primer Plan de Transmisión</a></li>
#                 <li><a href='/Portal/Planificacion/PlanTransmision/ActualizacionPTP'>Actualización Plan de Transmisión 2013 - 2022</a></li>
#                 <li><a href='/Portal/Planificacion/PlanTransmision/ActualizacionPTS'>Actualización Plan de Transmisión 2015 - 2024</a></li>
#                 <li><a href='/Portal/Planificacion/PlanTransmision/ActualizacionPTT'>Actualización Plan de Transmisión 2017 - 2026</a></li>
#                 <li><a href='/Portal/Planificacion/PlanTransmision/ActualizacionPTF'>Actualización Plan de Transmisión 2019 - 2028</a></li>
#                 <li><a href='/Portal/Planificacion/PlanTransmision/ActualizacionPTG'>Actualización Plan de Transmisión 2021 - 2030</a></li>
#                 <li><a href='/Portal/Planificacion/PlanTransmision/ActualizacionPTH'>Actualización Plan de Transmisión 2023 - 2032</a></li>
#                 <li><a href='/Portal/Planificacion/PlanTransmision/Fichas'>Fichas de Información</a></li>
#                     </ul>
#                 </li>
#                 <li><a href='/Portal/Planificacion/Interconexion/'>Estudios de Interconexiones Internacionales</a></li>
#                 <li><a href='/Portal/Planificacion/MargenReserva/'>Estudios de Verificación del Margen de Reserva Firme Objetivo del Sistema</a></li>
#                 <li><a href='/Portal/planificacion/otrosestudioslp'>Estudios especiales de Largo Plazo</a></li>
#             </ul>
#             <ul class='sub-nav-group'>
#                 <li><strong>Nuevos Proyectos</strong></li>
#                 <li>
#                     <ul>
#                 <li><a href='/Portal/Planificacion/NuevosProyectos/EstudiosPO'>Estudios de Pre Operatividad</a></li>
#                 <li><a href='/Portal/Planificacion/NuevosProyectos/EstudiosO'>Estudios de Operatividad</a></li>
#                 <li><a href='/Portal/Planificacion/NuevosProyectos/ConexionInstalacionSEIN'>Conexión de Instalaciones al SEIN (anterior PR-20)</a></li>
#                 <li><a href='/Portal/Planificacion/NuevosProyectos/OperacionComercial'>Operación Comercial e Integración (anterior PR-20)</a></li>
#                 <li><a href='/Portal/Planificacion/NuevosProyectos/IntegracionInstalacion'>Integración de Instalaciones al SEIN</a></li>
#                 <li><a href='/Portal/Planificacion/NuevosProyectos/OperacionComercialUnidades'>Operación Comercial de unidades o centrales de generación</a></li>
#                 <li><a href='/Portal/Planificacion/NuevosProyectos/ConclusionOperacion'>Conclusión de Operación Comercial y Retiro de Instalaciones del SEIN</a></li>
#                 <li><a href='/Portal/Planificacion/NuevosProyectos/ListaInstalaciones'>Lista de Instalaciones del STTN, STTR y STL</a></li>
#                 <li><a href='http://sw.coes.org.pe/psms/login.aspx' target='_blank'>Base de Datos - Protecciones (Station Ware)</a></li>
#                     </ul>
#                 </li>
#             </ul>
#         </div>
#     </li>
#     <li class='nav-item'>
#         <a href='#'>Operación</a>
#         <div class='sub-nav'>
#             <ul class='sub-nav-group'>
#                 <li><strong>Programa de Operación</strong></li>
#                 <li>
#                     <ul>
#                 <li><a href='/Portal/Operacion/ProgOperacion/ProgramaDiario'>Programa Diario</a></li>
#                 <li><a href='/Portal/Operacion/ProgOperacion/ActualizacionPD'>Actualización de Programa Diario</a></li>
#                 <li><a href='/Portal/Operacion/ProgOperacion/ProgSemanalOp'>Programa Semanal Operación</a></li>
#                 <li><a href='/Portal/Operacion/ProgOperacion/RprogDiarioOp'>Reprograma Diario de Operación</a></li>
#                 <li><a href='/Portal/Operacion/ProgOperacion/ProgMedianoPO'>Programa Mediano Plazo Operación</a></li>
#                     </ul>
#                 </li>
#                 <li><strong>Importación y Excedentes</strong></li>
#                 <li>
#                     <ul>
#                 <li><a href='/Portal/Operacion/ImportacionyExcedentes/CapacidadImport'>Capacidad de Importación</a></li>
#                 <li><a href='/Portal/Operacion/ImportacionyExcedentes/ExcedentesExp'>Excedentes de Exportación</a></li>
#                     </ul>
#                 </li>
#             </ul>
#             <ul class='sub-nav-group'>
#                 <li><strong>Programa de Mantenimiento</strong></li>
#                 <li>
#                     <ul>
#                 <li><a href='/Portal/Operacion/ProgManten/ProgDiario'>Programa Diario</a></li>
#                 <li><a href='/Portal/Operacion/ProgManten/ActualizacionPD'>Actualización de Programa Diario</a></li>
#                 <li><a href='/Portal/Operacion/ProgManten/ProgSemanal'>Programa Semanal</a></li>
#                 <li><a href='/Portal/Operacion/ProgManten/ProgMensual'>Programa Mensual</a></li>
#                 <li><a href='/Portal/Operacion/ProgManten/ProgAnual'>Programa Anual</a></li>
#                 <li><a href='/Portal/Operacion/ProgManten/ProgMantenimientoMayor'>Programa Mantenimiento Mayor</a></li>
#                     </ul>
#                 </li>
#                 <li><strong>Características del SEIN</strong></li>
#                 <li>
#                     <ul>
#                 <li><a href='/Portal/Operacion/CaractSEIN/BaseDatos'>Base de Datos</a></li>
#                 <li><a href='/Portal/equipamiento/equipo/index'>Equipamiento</a></li>
#                 <li><a href='/Portal/FichaTecnica/FichaTecnica'>Ficha Técnica</a></li>
#                 <li><a href='/Portal/Operacion/CaractSEIN/MapaSEIN'>Mapa del SEIN</a></li>
#                 <li><a href='/Portal/Operacion/CaractSEIN/DiagramaUnifilar'>Diagrama Unifilar</a></li>
#                     </ul>
#                 </li>
#             </ul>
#             <ul class='sub-nav-group'>
#                 <li><strong>Estudios</strong></li>
#                 <li>
#                     <ul>
#                 <li><a href='/Portal/Operacion/Estudios/OperacionSEIN'>Operacion del SEIN</a></li>
#                 <li><a href='/Portal/Operacion/Estudios/Comercializacion'>Comercialización</a></li>
#                 <li><a href='/Portal/Operacion/Estudios/PotenciaEfectiva'>Potencia Efectiva</a></li>
#                 <li><a href='/Portal/Operacion/Estudios/PotenciaMinima'>Potencia Mínima</a></li>
#                 <li><a href='/Portal/Operacion/Estudios/HomologacionModelos'>Homologación de Modelos</a></li>
#                 <li><a href='/Portal/Operacion/Estudios/CostosVariables'>Costos Variables</a></li>
#                 <li><a href='/Portal/Operacion/Estudios/CostosVariablesNoCom'>Costos Variables no Combustibles</a></li>
#                 <li><a href='/Portal/Operacion/Estudios/Hidrologia'>Hidrología</a></li>
#                     </ul>
#                 </li>
#                 <li><a href='/Portal/Interconexiones/Reportes/MenuInterconexiones'>Intercambios Internacionales</a></li>
#             </ul>
#         </div>
#     </li>
#     <li class='nav-item'>
#         <a href='#'>Post Operación</a>
#         <div class='sub-nav'>
#             <ul class='sub-nav-group'>
#                 <li><strong>Demanda de los Agentes</strong></li>
#                 <li>
#                     <ul>
#                 <li><a href='/Portal/DemandaBarras/consulta/index?tipo=2'>Distribuidores</a></li>
#                 <li><a href='/Portal/DemandaBarras/consulta/index?tipo=4'>Usuarios Libres</a></li>
#                     </ul>
#                 </li>
#                 <li><strong>Reportes</strong></li>
#                 <li>
#                     <ul>
#                 <li><a href='/Portal/PostOperacion/Reportes/Idcos'>IDCOS</a></li>
#                 <li><a href='/Portal/PostOperacion/Reportes/Ieod'>IEOD</a></li>
#                 <li><a href='/Portal/portalinformacion/demanda?indicador=maxima'>Máxima Demanda</a></li>
#                 <li><a href='/Portal/PostOperacion/Reportes/ReporteIndisponibilidad'>Reporte de Indisponibilidad</a></li>
#                 <li><a href='/Portal/PostOperacion/Reportes/ReservaCompensableRPF'>Reserva Compensable por RPF</a></li>
#                 <li><a href='/Portal/PostOperacion/Reportes/HorasOperación'>Horas de Operación y Numeros de Arranques Anuales</a></li>
#                 <li><a href='/Portal//postoperacion/reportes/pruebasaleatorias'>Pruebas Aleatorias PR-25</a></li>
#                     </ul>
#                 </li>
#                 <li><strong>Evaluacion y Fallas</strong></li>
#                 <li>
#                     <ul>
#                 <li><a href='/Portal/PostOperacion/EvaluacionFallas/'>Evaluación y Fallas</a></li>
#                     </ul>
#                 </li>
#                 <li><strong>Reportes de Interés</strong></li>
#                 <li>
#                     <ul>
#                 <li><a href='/Portal/PostOperacion/ReportesInteres/AdecuacionNTIITR'>Adecuación a la NTIITR</a></li>
#                 <li><a href='/Portal/PostOperacion/ReportesInteres/SupervisionMantenimiento'>Supervisión Mantenimiento</a></li>
#                 <li><a href='/Portal/PostOperacion/ReportesInteres/SupervisionPlanificacion'>Supervisión Planificación</a></li>
#                 <li><a href='/Portal/PostOperacion/ReportesInteres/PlanTrabajoOPT'>Plan de Trabajo OPT</a></li>
#                     </ul>
#                 </li>
#                 <li><a href='/Portal/Eventos/Relevantes'>Eventos Relevantes</a></li>
#             </ul>
#             <ul class='sub-nav-group'>
#                 <li><strong>Transferencias (Antes del MME)</strong></li>
#                 <li>
#                     <ul>
#                 <li><a href='/Portal/PostOperacion/ValorizacionTransferencias/ValorizacionTransferenciaEP'>Valorizacion de Transferencia de Energia y Potencia</a></li>
#                 <li><a href='/Portal/postoperacion/valorizaciontransferencias/pagosstysct'>Asignaciones de Responsabilidad de Pago SST y SCT</a></li>
#                 <li><a href='/Portal/PostOperacion/ValorizacionTransferencias/FactoresProporcion'>Factores de Proporción</a></li>
#                 <li><a href='/Portal/PostOperacion/ValorizacionTransferencias/CálculoBalanceEF'>Cálculo y Balance de Energía Firme</a></li>
#                 <li><a href='/Portal/PostOperacion/ValorizacionTransferencias/CostosMarginalesCP'>Costos Marginales de Corto Plazo Para Licitaciones</a></li>
#                 <li><a href='/Portal/PostOperacion/ValorizacionTransferencias/ResarcimientosNTCSE'>Resarcimientos NTCSE</a></li>
#                     </ul>
#                 </li>
#                 <li><strong>Informes</strong></li>
#                 <li>
#                     <ul>
#                 <li><a href='/Portal/PostOperacion/Informes/EvaluacionSemanal'>Evaluación Semanal</a></li>
#                 <li><a href='/Portal/PostOperacion/Informes/EvaluacionMensual'>Evaluación Mensual</a></li>
#                 <li><a href='/Portal/PostOperacion/Informes/EvaluacionAnual'>Evaluación Anual</a></li>
#                 <li><a href='/Portal/PostOperacion/Informes/AnalisisEconomicoDespacho'>Análisis de la Ejecución del Despacho Económico</a></li>
#                 <li><a href='/Portal/PostOperacion/Informes/ReservaRotanteRPF'>Reserva Rotante para Regulación Primaria de Frecuencia</a></li>
#                 <li><a href='/Portal/PostOperacion/Informes/ReservaRotanteRSF'>Reserva Rotante para Regulación Secundaria de Frecuencia</a></li>
#                 <li><a href='/Portal/PostOperacion/Informes/UnidadesGeneracionPruebas'>Unidades de Generación por Pruebas</a></li>
#                 <li><a href='/Portal/PostOperacion/Informes/MagEnergiaDejadaInyectar'>Magnitud de Energía Dejada de Inyectar</a></li>
#                 <li><a href='/Portal/postoperacion/informes/listadours'>URS calificadas para Regulación Secundaria</a></li>
#                 <li><a href='/Portal/postoperacion/informes/compensacionconfiabilidad'>Compensación por Confiabilidad de Suministro (CCCSE)</a></li>
#                     </ul>
#                 </li>
#                 <li><strong>Gas Natural</strong></li>
#                 <li>
#                     <ul>
#                 <li><a href='/Portal/PostOperacion/GasNatural/DeclaracionPreciosGas'>Declaración de Precios de Gas</a></li>
#                 <li><a href='/Portal/PostOperacion/GasNatural/PreciosDeclarados'>Precios Declarados</a></li>
#                 <li><a href='/Portal/PostOperacion/GasNatural/DocumentosRelacionados'>Documentos relacionados</a></li>
#                     </ul>
#                 </li>
#             </ul>
#         </div>
#     </li>
#     <li class='nav-item'>
#         <a href='/Portal/mercadomayorista/general'>Mercado Mayorista</a>
#         <div class='sub-nav'>
#             <ul class='sub-nav-group'>
#                 <li><a href='/Portal/mercadomayorista/visualizaciondatos/listadoparticipantes'>Listado de Participantes</a></li>
#                 <li><a href='/Portal/browser/download?url=Marco%20Normativo%2FProcedimientos%2FTecnicos%2F02%20Condiciones%20de%20Participaci%C3%B3n%20en%20el%20Mercado%20Mayorista%20de%20Electricidad.pdf'>Condiciones y Requisitos del participante del MME</a></li>
#                 <li><a href='/Portal/mercadomayorista/formato/index'>Formatos para el MME</a></li>
#                 <li><a href='/Portal/mercadomayorista/garantiasyfideicomiso'>Garantías y Fideicomiso</a></li>
#                 <li><a href='/Portal/mercadomayorista/reporteindicadores'>Reporte de Indicadores para el monitoreo del MME</a></li>
#             </ul>
#             <ul class='sub-nav-group'>
#                 <li><strong>Costos Marginales de Corto Plazo</strong></li>
#                 <li>
#                     <ul>
#                 <li><a href='/Portal/mercadomayorista/costosmarginales/index'>Costos Marginal en Tiempo Real (preliminar)</a></li>
#                 <li><a href='/Portal/mercadomayorista/costosmarginales/revisados'>Costos Marginales Revisados</a></li>
#                     </ul>
#                 </li>
#                 <li><a href='/Portal/mercadomayorista/liquidaciones'>Liquidaciones del MME</a></li>
#                 <li><a href='/Portal/mercadomayorista/informeauditoria'>Auditoría a la metodología</a></li>
#             </ul>
#         </div>
#     </li>
#     <li class='nav-item'>
#         <a href='#'>Directorio e Impugnaciones</a>
#         <div class='sub-nav'>
#             <ul class='sub-nav-group'>
#                 <li><a href='/Portal/browser/download?url=Directorio%20e%20Impugnaciones%2FRequisitos%20y%20Plazos%2FRequisitosyplazosdeimpugnacion.doc'>Requisitos y Plazos</a></li>
#                 <li><a href='/Portal/browser/download?url=Directorio%20e%20Impugnaciones%2FModelos%20de%20Recursos%2FModelodeRecursodeApelacion.doc'>Modelos de Recursos</a></li>
#                 <li><a href='/Portal/DirectorioImpugnaciones/Impugnaciones/RecursosApelacion'>Recursos de apelación</a></li>
#                 <li><strong>Reconsideraciones</strong></li>
#                 <li>
#                     <ul>
#                 <li><a href='/Portal/DirectorioImpugnaciones/Impugnaciones/DireccionEjecutiva'>Dirección Ejecutiva</a></li>
#                 <li><a href='/Portal/DirectorioImpugnaciones/Impugnaciones/Directorio'>Directorio</a></li>
#                     </ul>
#                 </li>
#             </ul>
#             <ul class='sub-nav-group'>
#                 <li><strong>Arbitraje</strong></li>
#                 <li>
#                     <ul>
#                 <li><a href='/Portal/DirectorioImpugnaciones/Arbitraje/Solicitudes'>Solicitudes de Arbitraje</a></li>
#                 <li><a href='/Portal/DirectorioImpugnaciones/Arbitraje/LaudosArbitrales'>Laudos Arbitrales</a></li>
#                 <li><a href='/Portal/browser/download?url=Directorio%20e%20Impugnaciones%2FArbitraje%2FProcesos%20Arbitraje%2FProcesosArbitralesWEB.xls'>Procesos Arbitraje</a></li>
#                     </ul>
#                 </li>
#             </ul>
#             <ul class='sub-nav-group'>
#                 <li><strong>Directorio</strong></li>
#                 <li>
#                     <ul>
#                 <li><a href='/Portal/DirectorioImpugnaciones/Agenda/Directorio'>Agenda</a></li>
#                 <li><a href='/Portal/DirectorioImpugnaciones/Acuerdos/Directorio'>Acuerdos</a></li>
#                     </ul>
#                 </li>
#                 <li><strong>Asamblea</strong></li>
#                 <li>
#                     <ul>
#                 <li><a href='/Portal/DirectorioImpugnaciones/Agenda/Asamblea'>Agenda</a></li>
#                 <li><a href='/Portal/DirectorioImpugnaciones/Acuerdos/Asamblea'>Acuerdos</a></li>
#                     </ul>
#                 </li>
#             </ul>
#         </div>
#     </li>
#     <li class='nav-item'>
#         <a href='#'>Marco Normativo</a>
#         <div class='sub-nav'>
#             <ul class='sub-nav-group'>
#                 <li><a href='/Portal/MarcoNormativo/BaseLegal/'>Base Legal</a></li>
#                 <li><a href='/Portal/MarcoNormativo/Estatuto/'>Estatuto</a></li>
#                 <li><strong>Procedimientos</strong></li>
#                 <li>
#                     <ul>
#                 <li><a href='/Portal/MarcoNormativo/Procedimientos/Tecnicos'>Técnicos</a></li>
#                 <li><a href='/Portal/MarcoNormativo/Procedimientos/Administrativos'>Administrativos</a></li>
#                 <li><a href='/Portal/browser/download?url=Marco Normativo/Procedimientos/Glosario de Terminos/Glosario%20de%20T%C3%A9rminos.pdf'>Glosario de Términos</a></li>
#                 <li><strong>Propuestas de Procedimientos</strong></li>                <li>
#                     <ul>
#                       <li><a href='/Portal/MarcoNormativo/Proyectos/ConsultaIntegrantes'>Consulta a los Integrantes</a></li>
#                       <li><a href='http://www.osinergmin.gob.pe/seccion/institucional/regulacion-tarifaria/procesos-regulatorios/electricidad/aprobacion-procedimientos-coes' target='_blank'>Trámite de Aprobación por OSINERGMIN</a></li>
#                     </ul>
#                 </li>
#                     </ul>
#                 </li>
#             </ul>
#             <ul class='sub-nav-group'>
#                 <li><a href='/Portal/MarcoNormativo/DecisionesEjecutivasNotasTecnicas'>Decisiones Ejecutivas y Notas Técnicas</a></li>
#             </ul>
#         </div>
#     </li>
#     <li class='nav-item'>
#         <a href='#'>Organización</a>
#         <div class='sub-nav'>
#             <ul class='sub-nav-group'>
#                 <li><a href='/Portal/Organizacion/QuienesSomos'>Quiénes somos</a></li>
#                 <li><a href='/Portal/Organizacion/MisionVisionValores'>Misión, visión y valores</a></li>
#                 <li><a href='/Portal/Organizacion/CodigoEtica'>Código de ética</a></li>
#                 <li><a href='/Portal/Organizacion/PoliticaCalidad'>Política del COES</a></li>
#                 <li><a href='/Portal/Organizacion/EstructuraOrganizacional'>Estructura Organizacional</a></li>
#                 <li><a href='/Portal/Organizacion/Asamblea'>Asamblea</a></li>
#                 <li><a href='/Portal/Organizacion/Directorio'>Directorio</a></li>
#             </ul>
#         </div>
#     </li>
#     <li class='nav-item'>
#         <a href='#'>Integrantes</a>
#         <div class='sub-nav'>
#             <ul class='sub-nav-group'>
#                 <li><a href='/Portal/registrointegrante/integrante'>Registro de Integrantes</a></li>
#                 <li><a href='/Portal/registrointegrante/reporte/empresa'>Listado de Integrantes</a></li>
#                 <li><a href='/Portal/integrantes/index'>Información Adicional</a></li>
#                 <li><a href='/Portal/Integrantes/AportesIntegrantes'>Aportes de los Integrantes</a></li>
#             </ul>
#         </div>
#     </li>
#     <li class='nav-item'>
#         <a href='#'>Publicaciones</a>
#         <div class='sub-nav'>
#             <ul class='sub-nav-group'>
#                 <li><a href='/Portal/Publicaciones/Estadisticas/'>Estadísticas Anuales</a></li>
#                 <li><a href='/Portal/Publicaciones/Memorias/'>Memorias Anuales</a></li>
#                 <li><a href='/Portal/Publicaciones/Boletines/'>Boletines Mensuales</a></li>
#                 <li><a href='/Portal/Publicaciones/Informes/'>Informes Técnicos</a></li>
#                 <li><a href='/Portal/publicaciones/saladeprensa/AppMovil'>Sala de Prensa</a></li>
#             </ul>
#         </div>
#     </li>
# </ul>
#
#             </nav>
#         </div>
#         <div class="content">
#
# <script src="/Portal/Content/Scripts/carousel.js"></script>
# <link href="/Portal/Content/Css/carousel.css?v=1.0" rel="stylesheet" />
# <script src="/Portal/Content/Scripts/home.js?v=3.9"></script>
# <script src="/Portal/Content/Scripts/highstock.js"></script>
# <link href="/Portal/Content/Css/iconografia.css" rel="stylesheet" />
# <!--
# <script src="~/Content/Scripts/scroll.min.js"></script>
# <link href="~/Content/Css/scroll.min.css" rel="stylesheet" />
# -->
# <script src="/Portal/Content/Scripts/jquery.format.js"></script>
# <script src="/Portal/Content/Scripts/date.format.js"></script>
# <script src="/Portal/Content/Scripts/PortalInformacion/util.js"></script>
#
#
#
# <style type="text/css">
#     ::-webkit-scrollbar {
#         width: 10px;
#     }
#
#     ::-webkit-scrollbar-button {
#         background: #F1F1F1;
#     }
#
#     ::-webkit-scrollbar-track-piece {
#         background: #F1F1F1;
#     }
#
#     ::-webkit-scrollbar-thumb {
#         background: #C1C1C1;
#     }
#
#     .div-banner-enlace {
#         position: absolute;
#         top: 40px !important;
#         left: 900px;
#         background: none !important
#     }
#
#     .div-banner-enlace a {
#         background:none !important
#     }
#
#     .div-banner-enlace a img {
#         width: 50px;
#         height: 60px;
#     }
#
#
# </style>
#
# <div class="jcarousel-wrapper">
#     <div class="jcarousel">
#         <ul>
#             <li>
#                     <img src="https://www.coes.org.pe/fileapp/banners/BARRA_54.jpg" alt="" />
#
#                 <h1></h1>
#                 <span></span>
#                     <div><a href="/Portal/Operacion/Estudios/Hidrologia?path=Operaci%C3%B3n%2FEstudios%2FHidrologia%2FDiagramas%20Topol%C3%B3gicos%2F2021%2F">Conoce más</a></div>
#
#
#
#             </li>
#             <li>
#                     <img src="https://www.coes.org.pe/fileapp/banners/BARRA_53.jpg" alt="" />
#
#                 <h1></h1>
#                 <span></span>
#                     <div><a href="/Portal/portalinformacion/VisorPowerBI">Conoce más</a></div>
#
#
#
#             </li>
#             <li>
#                     <img src="https://www.coes.org.pe/fileapp/banners/BARRA_49.jpg" alt="" />
#
#                 <h1></h1>
#                 <span></span>
#                     <div><a href="/Portal/publicaciones/estadisticas/estadistica2020">Conoce más</a></div>
#
#
#
#             </li>
#             <li>
#                     <img src="https://www.coes.org.pe/fileapp/banners/BARRA_47.jpg" alt="" />
#
#                 <h1></h1>
#                 <span></span>
#                     <div><a href="/Portal/Planificacion/PlanTransmision/ActualizacionPTH?path=Planificaci%C3%B3n%2FPlan%20de%20Transmision%2FActualizaci%C3%B3n%20Plan%20de%20Transmisi%C3%B3n%202023%20-%202032%2F02.%20ID%202021-2030%2F">Conoce más</a></div>
#
#
#
#             </li>
#             <li>
#                     <img src="https://www.coes.org.pe/fileapp/banners/BARRA_43.jpg" alt="" />
#
#                 <h1></h1>
#                 <span></span>
#
#
#
#             </li>
#             <li>
#                     <img src="https://www.coes.org.pe/fileapp/banners/BARRA_52.jpg" alt="" />
#
#                 <h1></h1>
#                 <span></span>
#                     <div><a href="/Portal/portalinformacion/VisorPowerBI">Conoce más</a></div>
#
#
#
#             </li>
#             <li>
#                     <img src="https://www.coes.org.pe/fileapp/banners/BARRA_4.jpg" alt="" />
#
#                 <h1></h1>
#                 <span></span>
#                     <div><a href="/Portal/Publicaciones/Informes/">Conoce más</a></div>
#
#
#
#             </li>
#         </ul>
#     </div>
#     <p class="jcarousel-pagination">
#     </p>
# </div>
# <div class="clearer"></div>
# <div class="home-content">
#       <div class="home-layout">
#
#           <div>
#               <a href="/Portal/portalinformacion/generacion">
#                   <div class="modulo-enlace home-portalinfo">
#                       <div></div>
#                       <div>
#                           <span class="icono-stats-bars"></span>
#                       </div>
#                       <div></div>
#                       <div>
#                           <strong>Portal de Indicadores</strong><br />
#                           <span>
#                               Indicadores importantes del Sector Energético Peruano
#                           </span>
#                       </div>
#                   </div>
#               </a>
#
#
#
#               <div class="home-subtit">Accesos Directos</div>
#               <div class="home-item-list">
#                   <div class="item-programa"><a href="/Portal/operacion/progoperacion/programadiario">Programación de la Operación</a></div>
#                   <div class="item-valorizacion"><a href="/Portal/MercadoMayorista/CostosMarginales/Index">Costos Marginales en Tiempo Real</a></div>
#                   <div class="item-evaluacion"><a href="/Portal/PostOperacion/EvaluacionFallas/">Evaluación y Fallas (Análisis de Eventos / Fallas)</a></div>
#                   <div class="item-valorizacion"><a href="/Portal/mercadomayorista/liquidaciones">Liquidaciones Mercado Mayorista de Electricidad</a></div>
#                   <div class="item-procedimientos"><a href="/Portal/MarcoNormativo/Procedimientos/Tecnicos">Procedimientos Técnicos</a></div>
#                   <div class="item-caracteristicas"><a href="/Portal/Operacion/CaractSEIN/BaseDatos">Características del SEIN</a></div>
#                   <div class="item-publicaciones"><a href="/Portal/Publicaciones/Boletines/">Publicaciones</a></div>
#                   <div class="item-reporte"><a href="/Portal/portalinformacion/demanda?indicador=maxima">Reporte de Máxima Demanda</a></div>
#                   <div class="item-atencion"><a href="/Portal/contacto/index">Atención al Cliente</a></div>
#                   <div class="item-procedimientos"><a href="/Portal/publicaciones/suscripcion/suscripcion">Suscripciones</a></div>
#                   <div class="item-agenda"><a href="JavaScript:openAgenda();">Agenda de Directorio</a></div>
#                   <div class="item-calendar"><a href="JavaScript:openCalendario();">Calendario COES</a></div>
#               </div>
#
#               <div class="clearer20"></div>
#               <div class="home-subtit">Sitios de Interés</div>
#               <div class="home-item-list">
#                   <div class="item-senamhi"><a href="http://www.senamhi.gob.pe/" target="_blank">Senamhi</a></div>
#                   <div class="item-osinergmin"><a href="http://www.osinergmin.gob.pe/" target="_blank">Osinergmin</a></div>
#                   <div class="item-ministerio"><a href="http://www.minem.gob.pe/" target="_blank">Ministerio de Energía y Minas</a></div>
#               </div>
#           </div>
#           <div>
#
#               <a href="/Portal/portalinformacion/VisorPowerBI">
#                   <div class="modulo-enlace home-powerbi">
#                       <div></div>
#                       <div>
#                           <span class="icono-stats-dots"></span>
#                       </div>
#                       <div></div>
#                       <div>
#                           <strong>Indicadores BI</strong><br />
#                           <span>
#                               Datos históricos
#                           </span>
#                       </div>
#                   </div>
#               </a>
#
#
#
#               <div class="home-indicador-title">
#                   Seleccione:
#                   <select id="cbGrafico">
#                       <option value="1">Frecuencia del SEIN</option>
#                       <option value="2">Demanda</option>
#                       <option value="3">Producción</option>
#                   </select>
#               </div>
#               <div class="home-indicador-subtitle" id="resumenIndicador">
#               </div>
#               <div class="home-indicador-grafico">
#                   <div id="chartIndicador" class="grafico-home"></div>
#                   <div style="clear:both"></div>
#               </div>
#
#
#
#           </div>
#
#           <div>
#
#               <a href="/Portal/tramitevirtual/registro/principal">
#                   <div class="modulo-enlace home-portaltramite">
#                       <div></div>
#                       <div>
#                           <span class="icono-books"></span>
#                       </div>
#                       <div></div>
#                       <div>
#                           <strong>  Portal de Trámite Virtual</strong><br />
#                           <span>
#                               Realice sus trámites en línea
#                           </span>
#                       </div>
#                   </div>
#               </a>
#
#               <div id="tab-container" class='tab-container'>
#                   <ul class='etabs'>
#                       <li class='tab-home'><a href="#paso1">Eventos relevantes</a></li>
#                       <li class='tab-home'><a href="#paso2">Máxima Demanda</a></li>
#                       <li class='tab-home'><a href="#paso3">Sala de Prensa</a></li>
#                   </ul>
#
#                   <div class='panel-container'>
#                       <div id="paso1">
#                           <div id="contentHolderEvento" class="content-holder">
#                                   <div class="content-comunicado">
#                                       <div class="comunicado-header">
#                                           <div class="comunicado-fecha">17 FEB.</div>
#                                           <div class="comunicado-title"><a href="eventos/relevantes/" style="color:#2980B9">DESCONECT&#211; LA L&#205;NEA L-6007 (PUNO – TUCARI) DE 60 KV POR FALLA NO INFORMADA POR SU PROPIETARIO MINERA ARUNTANI</a></div>
#                                           <div class="clearer"></div>
#                                       </div>
#                                       <div class="comunicado-content">
#                                           Desconect&#243; la l&#237;nea L-6007 (Puno – Tucari) de 60 kV por falla no informada por su propietario Minera Aruntani. Se interrumpi&#243; la carga de la Minera Aruntani 2 MW aproximadamente. La l&#237;nea continua desconectada por revisi&#243;n
#                                       </div>
#                                   </div>
#                                   <div class="clearer"></div>
#                                   <div class="content-comunicado">
#                                       <div class="comunicado-header">
#                                           <div class="comunicado-fecha">17 FEB.</div>
#                                           <div class="comunicado-title"><a href="eventos/relevantes/" style="color:#2980B9">DECLARACI&#211;N DE SITUACI&#211;N EXCEPCIONAL EN LAS SUBESTACIONES PACHACHUTEC Y PROGRESO
# </a></div>
#                                           <div class="clearer"></div>
#                                       </div>
#                                       <div class="comunicado-content">
#                                           Se declar&#243; situaci&#243;n excepcional en las subestaciones Pachac&#250;tec y Progreso debido a la desconexi&#243;n de las l&#237;neas L-2133 (Manchay - Pachac&#250;tec) y L-2135 (Pachac&#250;tec - Progreso) de 220 kV por regulaci&#243;n de tensi&#243;n en Lima.
#                                       </div>
#                                   </div>
#                                   <div class="clearer"></div>
#                                   <div class="content-comunicado">
#                                       <div class="comunicado-header">
#                                           <div class="comunicado-fecha">16 FEB.</div>
#                                           <div class="comunicado-title"><a href="eventos/relevantes/" style="color:#2980B9">DESCONECT&#211; LA CT CALLAO CON 2 MW POR FALLA QUE SE INVESTIGA</a></div>
#                                           <div class="clearer"></div>
#                                       </div>
#                                       <div class="comunicado-content">
#                                           Desconect&#243; la CT Callao con 2 MW por falla que se investiga. No se report&#243; interrupci&#243;n de suministros. La central contin&#250;a indisponible para su revisi&#243;n.
#                                       </div>
#                                   </div>
#                                   <div class="clearer"></div>
#                                   <div class="content-comunicado">
#                                       <div class="comunicado-header">
#                                           <div class="comunicado-fecha">16 FEB.</div>
#                                           <div class="comunicado-title"><a href="eventos/relevantes/" style="color:#2980B9">DESCONECT&#211; LA C.H. SAN IGNACIO POR FALLA</a></div>
#                                           <div class="clearer"></div>
#                                       </div>
#                                       <div class="comunicado-content">
#                                           Desconect&#243; la C.H. San Ignacio con 0.39 MW por falla debido a descargas atmosf&#233;ricas en la zona de Caylloma, seg&#250;n lo informado por Statkraft, titular de la central. No se report&#243; interrupci&#243;n de suministros. A las 21:37 h, la central sincroniz&#243; con el SEIN.
#                                       </div>
#                                   </div>
#                                   <div class="clearer"></div>
#                                   <div class="content-comunicado">
#                                       <div class="comunicado-header">
#                                           <div class="comunicado-fecha">16 FEB.</div>
#                                           <div class="comunicado-title"><a href="eventos/relevantes/" style="color:#2980B9">DESCONECT&#211; EL GENERADOR G2 DE LA C.H. CAHUA  POR FALLA</a></div>
#                                           <div class="clearer"></div>
#                                       </div>
#                                       <div class="comunicado-content">
#                                           Desconect&#243; el generador G2 de la C.H. Cahua con 20.82 MW por actuaci&#243;n de su sistema de protecci&#243;n, debido a la p&#233;rdida de comunicaci&#243;n con el PLC , seg&#250;n lo informado por Statkraft, titular del generador. No se present&#243; interrupci&#243;n de suministros en el SEIN. El generador qued&#243; fuera de servicio para su inspecci&#243;n. A las 02:46 h el generador G2 sincroniz&#243; con el SEIN.
#                                       </div>
#                                   </div>
#                                   <div class="clearer"></div>
#                           </div>
#                           <div class="enlace-evento">
#                               <a href="/Portal/eventos/relevantes/" style="color:#2980B9">Ver todos los eventos</a>
#                           </div>
#                           <div style="clear:both"></div>
#                       </div>
#                       <div id="paso2">
#                           <div id="contentHolderComunicado" class="content-holder">
#                                   <div class="content-comunicado">
#                                       <div class="comunicado-header">
#                                           <div class="comunicado-fecha">02 FEB.</div>
#                                           <div class="comunicado-title">
#
# M&#193;XIMA DEMANDA ENERO 2022
#
#                                               <br />
#                                               <span style="font-size:12px; font-weight:normal">Fecha Publicación: 02/02/2022 18:06</span>
#                                           </div>
#
#
#                                           <div class="clearer"></div>
#                                       </div>
#                                       <div class="comunicado-content">
#
# La m&#225;xima demanda ocurri&#243; a las 20:45 horas del
# martes 11 de enero, con 7 009,292 MW.
#                                           <div>
#                                               <a href="https://www.coes.org.pe/Portal/portalinformacion/d
# emanda?indicador=maxima">Ver más</a>
#                                           </div>
#                                       </div>
#
#                                   </div>
#                                   <div class="clearer"></div>
#                                   <div class="content-comunicado">
#                                       <div class="comunicado-header">
#                                           <div class="comunicado-fecha">02 ENE.</div>
#                                           <div class="comunicado-title">
#
# M&#193;XIMA DEMANDA DICIEMBRE 2021
#
#                                               <br />
#                                               <span style="font-size:12px; font-weight:normal">Fecha Publicación: 02/01/2022 20:24</span>
#                                           </div>
#
#
#                                           <div class="clearer"></div>
#                                       </div>
#                                       <div class="comunicado-content">
#                                           La m&#225;xima demanda ocurri&#243; a las 19:45 horas del
# lunes 13 de diciembre con 7 173,033 MW
#                                           <div>
#                                               <a href="https://www.coes.org.pe/Portal/portalinformacion/demanda?indicador=maxima">Ver más</a>
#                                           </div>
#                                       </div>
#
#                                   </div>
#                                   <div class="clearer"></div>
#                                   <div class="content-comunicado">
#                                       <div class="comunicado-header">
#                                           <div class="comunicado-fecha">02 DIC.</div>
#                                           <div class="comunicado-title">
#
# MAXIMA DEMANDA NOVIEMBRE 2021
#
#                                               <br />
#                                               <span style="font-size:12px; font-weight:normal">Fecha Publicación: 02/12/2021 19:15</span>
#                                           </div>
#
#
#                                           <div class="clearer"></div>
#                                       </div>
#                                       <div class="comunicado-content">
#
# La m&#225;xima demanda ocurri&#243; a las 19:30 horas, del
#
# ...
#                                               <a href="https://www.coes.org.pe/Portal/portalinformacion/demanda?indicador=maxima">Ver más</a>
#                                           </div>
#                                       </div>
#
#                                   </div>
#                                   <div class="clearer"></div>
#                                   <div class="content-comunicado">
#                                       <div class="comunicado-header">
#                                           <div class="comunicado-fecha">02 ABR.</div>
#                                           <div class="comunicado-title">
#                                               M&#193;XIMA DEMANDA MARZO 2020
#
#                                               <br />
#                                               <span style="font-size:12px; font-weight:normal">Fecha Publicación: 02/04/2020 18:10</span>
#                                           </div>
#
#
#                                           <div class="clearer"></div>
#                                       </div>
#                                       <div class="comunicado-content">
#                                           La m&#225;xima demanda ocurri&#243; a las 19:45 horas del lunes 09 de marzo, con 7 116,789 MW
#                                           <div>
#                                               <a href="https://www.coes.org.pe/Portal/portalinformacion/demanda?indicador=maxima">Ver más</a>
#                                           </div>
#                                       </div>
#
#                                   </div>
#                                   <div class="clearer"></div>
#                                   <div class="content-comunicado">
#                                       <div class="comunicado-header">
#                                           <div class="comunicado-fecha">02 MAR.</div>
#                                           <div class="comunicado-title">
#                                               M&#193;XIMA DEMANDA FEBRERO 2020
#
#                                               <br />
#                                               <span style="font-size:12px; font-weight:normal">Fecha Publicación: 02/03/2020 18:15</span>
#                                           </div>
#
#
#                                           <div class="clearer"></div>
#                                       </div>
#                                       <div class="comunicado-content">
#                                           La m&#225;xima demanda ocurri&#243; a las 19:30 horas, del martes 25 de febrero con 7 125,299 MW
#                                           <div>
#                                               <a href="https://www.coes.org.pe/Portal/portalinformacion/demanda?indicador=maxima">Ver más</a>
#                                           </div>
#                                       </div>
#
#                                   </div>
#                                   <div class="clearer"></div>
#                                   <div class="content-comunicado">
#                                       <div class="comunicado-header">
#                                           <div class="comunicado-fecha">02 FEB.</div>
#                                           <div class="comunicado-title">
#                                               M&#193;XIMA DEMANDA ENERO 2020
#
#                                               <br />
#                                               <span style="font-size:12px; font-weight:normal">Fecha Publicación: 02/02/2020 18:24</span>
#                                           </div>
#
#
#                                           <div class="clearer"></div>
#                                       </div>
#                                       <div class="comunicado-content">
#                                           La m&#225;xima demanda ocurri&#243; a las 19:30 horas, del viernes 24 de enero con 7 070,628 MW
#                                           <div>
#                                               <a href="https://www.coes.org.pe/Portal/portalinformacion/demanda?indicador=maxima">Ver más</a>
#                                           </div>
#                                       </div>
#
#                                   </div>
#                                   <div class="clearer"></div>
#                                   <div class="content-comunicado">
#                                       <div class="comunicado-header">
#                                           <div class="comunicado-fecha">02 ENE.</div>
#                                           <div class="comunicado-title">
#                                               M&#193;XIMA DEMANDA DICIEMBRE 2019
#
#                                               <br />
#                                               <span style="font-size:12px; font-weight:normal">Fecha Publicación: 02/01/2020 18:49</span>
#                                           </div>
#
#
#                                           <div class="clearer"></div>
#                                       </div>
#                                       <div class="comunicado-content">
#                                           La m&#225;xima demanda ocurri&#243; a las 19:30 horas, del lunes 02 de diciembre con 7 017,571 MW
#                                           <div>
#                                               <a href="https://www.coes.org.pe/Portal/portalinformacion/demanda?indicador=maxima">Ver más</a>
#                                           </div>
#                                       </div>
#
#                                   </div>
#                                   <div class="clearer"></div>
#                                   <div class="content-comunicado">
#                                       <div class="comunicado-header">
#                                           <div class="comunicado-fecha">02 DIC.</div>
#                                           <div class="comunicado-title">
#                                               M&#193;XIMA DEMANDA NOVIEMBRE 2019
#
#                                               <br />
#                                               <span style="font-size:12px; font-weight:normal">Fecha Publicación: 02/12/2019 19:26</span>
#                                           </div>
#
#
#                                           <div class="clearer"></div>
#                                       </div>
#                                       <div class="comunicado-content">
#                                           La m&#225;xima demanda ocurri&#243; a las 20:00 horas, del jueves 21 de noviembre con 6 928,228 MW
#                                           <div>
#                                               <a href="https://www.coes.org.pe/Portal/portalinformacion/demanda?indicador=maxima">Ver más</a>
#                                           </div>
#                                       </div>
#
#                                   </div>
#                                   <div class="clearer"></div>
#                                   <div class="content-comunicado">
#                                       <div class="comunicado-header">
#                                           <div class="comunicado-fecha">02 NOV.</div>
#                                           <div class="comunicado-title">
#                                               M&#193;XIMA DEMANDA OCTUBRE 2019
#
#                                               <br />
#                                               <span style="font-size:12px; font-weight:normal">Fecha Publicación: 02/11/2019 16:48</span>
#                                           </div>
#
#
#                                           <div class="clearer"></div>
#                                       </div>
#                                       <div class="comunicado-content">
#                                           La m&#225;xima demanda ocurri&#243; a las 19:00 horas, del martes 29 de noviembre con 6 840,568 MW
#                                           <div>
#                                               <a href="https://www.coes.org.pe/Portal/portalinformacion/demanda?indicador=maxima">Ver más</a>
#                                           </div>
#                                       </div>
#
#                                   </div>
#                                   <div class="clearer"></div>
#                                   <div class="content-comunicado">
#                                       <div class="comunicado-header">
#                                           <div class="comunicado-fecha">02 OCT.</div>
#                                           <div class="comunicado-title">
#                                               M&#193;XIMA DEMANDA SETIEMBRE 2019
#
#                                               <br />
#                                               <span style="font-size:12px; font-weight:normal">Fecha Publicación: 02/10/2019 17:49</span>
#                                           </div>
#
#
#                                           <div class="clearer"></div>
#                                       </div>
#                                       <div class="comunicado-content">
#                                           La m&#225;xima demanda ocurri&#243; a las 18:45 horas del martes 10 de setiembre con 6 672,276 MW
#                                           <div>
#                                               <a href="https://www.coes.org.pe/Portal/portalinformacion/demanda?indicador=maxima">Ver más</a>
#                                           </div>
#                                       </div>
#
#                                   </div>
#                                   <div class="clearer"></div>
#                                   <div class="content-comunicado">
#                                       <div class="comunicado-header">
#                                           <div class="comunicado-fecha">02 SEP.</div>
#                                           <div class="comunicado-title">
#                                               M&#193;XIMA DEMANDA AGOSTO 2019
#
#                                               <br />
#                                               <span style="font-size:12px; font-weight:normal">Fecha Publicación: 02/09/2019 18:46</span>
#                                           </div>
#
#
#                                           <div class="clearer"></div>
#                                       </div>
#                                       <div class="comunicado-content">
#                                           La m&#225;xima demanda ocurri&#243; a las 19:30 horas del lunes 26 de agosto con 6 728,480 MW
#                                           <div>
#                                               <a href="https://www.coes.org.pe/Portal/portalinformacion/demanda?indicador=maxima">Ver más</a>
#                                           </div>
#                                       </div>
#
#                                   </div>
#                                   <div class="clearer"></div>
#                           </div>
#                       </div>
#                       <div id="paso3">
#                           <div id="contentHolderSalaPrensa" class="content-holder" style="overflow-y:hidden">
#
#                               <div class="content-comunicado">
#                                   <div class="comunicado-header">
#                                       <div class="comunicado-fecha">19 Abr.</div>
#                                       <div class="comunicado-title">
#                                           Reconocimiento Internacional a Principales Directivos del COES:
#                                           <br />
#                                           "Ingeniero Eminente del IEEE Latinoamérica"
#                                           <br />
#                                       </div>
#                                       <div class="clearer"></div>
#                                   </div>
#                                   <div class="comunicado-content">
#                                       Se realizó la noche de Reconocimientos de la Sección Perú del IEEE, ceremonia donde
#                                       se premió al Ingeniero César Butrón Fernández, como Ingeniero Eminente del IEEE Latinoamérica 2017.
#                                       <div>
#                                           <a href="/Portal/organizacion/salaprensa">Ver más</a>
#                                       </div>
#                                   </div>
#                               </div>
#                               <div class="content-comunicado">
#                                   <div class="comunicado-header">
#                                       <div class="comunicado-fecha">16 Ene.</div>
#                                       <div class="comunicado-title">
#                                           Condecoración al COES como la "Institución del 2016"
#                                           <br />
#                                       </div>
#                                       <div class="clearer"></div>
#                                   </div>
#                                   <div class="comunicado-content">
#                                       Con motivo de celebrar su 74° Aniversario, además del Día del Ingeniero Electricista y el Día de la
#                                       Industria Eléctrica, la Asociación Electrotécnica Peruana (AEP) programó una serie de actividades
#                                       en la semana del 16 al 20 de enero 2017.
#                                       <div>
#                                           <a href="/Portal/organizacion/salaprensa/#coesinstitucion">Ver más</a>
#                                       </div>
#                                   </div>
#                               </div>
#                               <div class="clearer"></div>
#                           </div>
#                       </div>
#                   </div>
#               </div>
#           </div>
#    </div>
#
# </div>
# <div class="clearer"></div>
#
# <div id="popupAgenda" class="general-popup" style="width:500px">
#     <div><span class="button b-close"><span>X</span></span></div>
#
#     <div class="popup-text">
#         <div class="popup-title" style="text-align:center; margin-top:0"><span>Lista de anexos para el apoyo de cada área</span></div>
#         <p>
#             Si usted desea realizar alguna consulta especifica, a seguir les hacemos llegar una lista de anexos para que sea atendido por los
#             especialistas designados de cada área, puede contactarse a través del (511) 611-8585, ingresando los siguientes anexos según corresponda:
#         </p>
#
#         <div id="contenidoAgenda">
#
#         </div>
#         <br />
#         <p>
#             En caso de no conocer exactamente la Sub Dirección o Departamento para tu consulta, puedes comunicarte a los anexos de la Dirección respectiva,
#             donde  se te canalizará con el  especialiista encargado .
#         </p>
#     </div>
# </div>
#         </div>
#         <div class="footer">
#             <div class="footer-terms">
#                 <strong>COES © Todos los derechos reservados</strong><br />
#                 <span>Av. Los Conquistadores N° 1144, piso 2 - San Isidro, Lima - Perú. Teléfono: (511) 611-8585</span>
#                 <span style="font-size:12px">Horario de recepción de documentos: Lunes a Viernes de 07:30 am a 06:00 pm</span>
#             </div>
#             <div class="footer-social">
#                 <a href="/Portal/contacto/index"><img src="/Portal/Content/Images/Icons/contacto.png" /></a>
#             </div>
#         </div>
#     </div>
#     <div id="loading" class="loading">
#         <div class="loading-image">
#             <img src="/Portal/Content/Images/loading.gif" />
#         </div>
#     </div>
#     <div id="popupCalendario" class="general-popup" style="width:100%; height:825px">
#         <div><span class="button b-close"><span>X</span></span></div>
#         <div id="contenidoCalendario">
#         </div>
#     </div>
# </body>
# </html>: 0

# %%
#obtengo los datos de la página web
url = "http://www.coes.org.pe/portal/portalinformacion/demanda"
query = requests.utils.urlparse(url)
query

# %%
import requests
import pandas as pd
sess = requests.Session()
FI='06/04/2020'
FF='08/04/2020'
url = "http://www.coes.org.pe/portal/portalinformacion/demanda?fechaInicial="+FI+"&fechaFinal="+FF
r = sess.post(url)
#soup = BeautifulSoup(r.text)
datos = r.json()
data = datos['Data']
df = pd.DataFrame(columns={'Fecha','Ejecutado','Prog. Diaria','Prog. Semanal'})
for i in data:
    fecha,ejec,diario,sem = [i['Fecha']],[i['ValorEjecutado']],[i['ValorProgramacionDiaria']],[i['ValorProgramacionSemanal']]
    dfpequeño = pd.DataFrame(data={'Fecha':fecha,
                                   'Ejecutado':ejec,
                                   'Prog. Diaria':diario,
                                   'Prog. Semanal':sem})
    df = df.append(dfpequeño,ignore_index=True,sort=True)
    
df=df[['Fecha','Ejecutado','Prog. Diaria','Prog. Semanal']]
df

# %%
soup = BeautifulSoup(datos_dem)
tags = soup('link')
table=soup.find('table',class_='tabla-informacion') 
#table=soup.find('div',id='contenidoDemanda')
soup.findAll('table')[0].findAll('tr')
rows = table.find_all('tr')
for row in rows:
    print(row.text)

# %%
"""url='http://www.coes.org.pe/portal/portalinformacion/demanda'
requests.post(url=url, verify=False)
html = requests.get(url,verify=False).content
df_list = pd.read_html(html)
df = df_list[3]
df"""

# %%
from scrapy.item import Field
